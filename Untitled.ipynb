# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned_data.csv',encoding='latin1',low_memory=False)

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country     Latitude     Longitude Injury.Severity  \
# 0  MOOSE CREEK, ID  United States  3994.505315  46456.376210        Fatal(2)
# 1   BRIDGEPORT, CA  United States  3994.505315  46456.376210        Fatal(4)
# 2    Saltville, VA  United States    36.922223    -81.878056        Fatal(3)
# 3       EUREKA, CA  United States  3994.505315  46456.376210        Fatal(2)
# 4       Canton, OH  United States  3994.505315  46456.376210        Fatal(1)
#
#   Aircraft.damage  ... Amateur.Built Number.of.Engines Engine.Type  \
# 0       Destroyed  ...            No          1.000000     Unknown
# 1       Destroyed  ...            No          1.000000     Unknown
# 2       Destroyed  ...            No          1.000000     Unknown
# 3       Destroyed  ...            No          1.000000     Unknown
# 4       Destroyed  ...            No          1.146585     Unknown
#
#   Purpose.of.flight Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0          Personal                  2.0                0.000000
# 1          Personal                  4.0                0.000000
# 2          Personal                  3.0                0.279881
# 3          Personal                  2.0                0.000000
# 4          Personal                  1.0                2.000000
#
#   Total.Minor.Injuries Total.Uninjured  Weather.Condition   Report.Status
# 0             0.000000         0.00000                UNK  Probable Cause
# 1             0.000000         0.00000                UNK  Probable Cause
# 2             0.357061         5.32544                IMC  Probable Cause
# 3             0.000000         0.00000                IMC  Probable Cause
# 4             0.357061         0.00000                VMC  Probable Cause
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Injury.Severity',
#        'Aircraft.damage', 'Aircraft.Category', 'Registration.Number', 'Make',
#        'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition',
#        'Report.Status'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
